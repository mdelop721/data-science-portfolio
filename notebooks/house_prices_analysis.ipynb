# %% [markdown]
# # Análisis de Precios de Viviendas
# Este cuaderno es un ejemplo de cómo presentar un proyecto de Data Science.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
df = pd.read_csv('../data/sample_data.csv')
print(df.head())
